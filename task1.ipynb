# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("The number is even")
else:
    print("The number is odd")
# Out:
# The number is even

# %%
num = int(input("Enter a number: "))

if (num//2)*2 == num:
    print("The number is even")
else:
    print("The number is odd")
# Out:
# The number is even

# %%
num = int(input("Enter a number: "))
if num % 2 != 0:
    print("The number is odd")
else:
    print("The number is even")

# %%
num = int(input("Enter a number: "))

if (num // 2) * 2 != num:
    print("The number is odd")
else:
    print("The number is even")
# Out:
# The number is odd
